# %%
import pandas as pd
import os
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
import yfinance as yf
import numpy as np
import numpy as np
import pandas as pd
from joblib import Parallel, delayed
from fastdtw import fastdtw
from tqdm import tqdm
import tslearn
import tslearn.metrics
from sklearn.preprocessing import MinMaxScaler
import warnings

warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.simplefilter(action='ignore', category=FutureWarning)
#warnings.simplefilter(action='ignore', category=CollinearityWarning)
import warnings

from perform_utils import *
from scipy.stats import skew, kurtosis
import matplotlib.pyplot as plt
from matplotlib import cm
import pandas as pd
import seaborn as sns

cmap_blue = cm.get_cmap('Blues')
cmap_red = cm.get_cmap('Reds')

def beta_calculation(y,x):
    
    x = x.pct_change().iloc[1:]
    x = x.to_frame()
    x = x.values
    
    y = y.pct_change().iloc[1:]
    y = y.to_frame()
    y = y.values
    
    
    x = add_constant(x)
    model = OLS(y,x).fit()
    x = x[:, 1]
    
    return model.params[1]

# %%
TS_JPM_us                = list(pd.read_csv("./pairs/TS_JPM_us.csv")["0"])
TS_JPM_tse               = list(pd.read_csv("./pairs/TS_JPM_tse.csv")["0"])
TS_JPM_sse               = list(pd.read_csv("./pairs/TS_JPM_sse.csv")["0"])
TS_JPM_szse              = list(pd.read_csv("./pairs/TS_JPM_szse.csv")["0"])
SS_JPM_us                = list(pd.read_csv("./pairs/SS_JPM_us.csv")["0"])
SS_JPM_tse               = list(pd.read_csv("./pairs/SS_JPM_tse.csv")["0"])
SS_JPM_sse               = list(pd.read_csv("./pairs/SS_JPM_sse.csv")["0"])
SS_JPM_szse              = list(pd.read_csv("./pairs/SS_JPM_szse.csv")["0"])
SS_JPM_corr1_us          = list(pd.read_csv("./pairs/SS_JPM_corr1_us.csv")["0"])
SS_JPM_corr1_tse =         list(pd.read_csv("./pairs/SS_JPM_corr1_tse.csv")["0"])
SS_JPM_corr1_sse =         list(pd.read_csv("./pairs/SS_JPM_corr1_sse.csv")["0"])
SS_JPM_corr1_szse =        list(pd.read_csv("./pairs/SS_JPM_corr1_szse.csv")["0"])
SS_JPM_corr2_us =          list(pd.read_csv("./pairs/SS_JPM_corr2_us.csv")["0"])
SS_JPM_corr2_tse =         list(pd.read_csv("./pairs/SS_JPM_corr2_tse.csv")["0"])
SS_JPM_corr2_sse =         list(pd.read_csv("./pairs/SS_JPM_corr2_sse.csv")["0"])
SS_JPM_corr2_szse =        list(pd.read_csv("./pairs/SS_JPM_corr2_szse.csv")["0"])

TS_PFE_us                = list(pd.read_csv("./pairs/TS_PFE_us.csv")["0"])
TS_PFE_tse               = list(pd.read_csv("./pairs/TS_PFE_tse.csv")["0"])
TS_PFE_sse               = list(pd.read_csv("./pairs/TS_PFE_sse.csv")["0"])
TS_PFE_szse              = list(pd.read_csv("./pairs/TS_PFE_szse.csv")["0"])
SS_PFE_us                = list(pd.read_csv("./pairs/SS_PFE_us.csv")["0"])
SS_PFE_tse               = list(pd.read_csv("./pairs/SS_PFE_tse.csv")["0"])
SS_PFE_sse               = list(pd.read_csv("./pairs/SS_PFE_sse.csv")["0"])
SS_PFE_szse              = list(pd.read_csv("./pairs/SS_PFE_szse.csv")["0"])
SS_PFE_corr1_us          = list(pd.read_csv("./pairs/SS_PFE_corr1_us.csv")["0"])
SS_PFE_corr1_tse =         list(pd.read_csv("./pairs/SS_PFE_corr1_tse.csv")["0"])
SS_PFE_corr1_sse =         list(pd.read_csv("./pairs/SS_PFE_corr1_sse.csv")["0"])
SS_PFE_corr1_szse =        list(pd.read_csv("./pairs/SS_PFE_corr1_szse.csv")["0"])
SS_PFE_corr2_us =          list(pd.read_csv("./pairs/SS_PFE_corr2_us.csv")["0"])
SS_PFE_corr2_tse =         list(pd.read_csv("./pairs/SS_PFE_corr2_tse.csv")["0"])
SS_PFE_corr2_sse =         list(pd.read_csv("./pairs/SS_PFE_corr2_sse.csv")["0"])
SS_PFE_corr2_szse =        list(pd.read_csv("./pairs/SS_PFE_corr2_szse.csv")["0"])

TS_SBUX_us                = list(pd.read_csv("./pairs/TS_SBUX_us.csv")["0"])
TS_SBUX_tse               = list(pd.read_csv("./pairs/TS_SBUX_tse.csv")["0"])
TS_SBUX_sse               = list(pd.read_csv("./pairs/TS_SBUX_sse.csv")["0"])
TS_SBUX_szse              = list(pd.read_csv("./pairs/TS_SBUX_szse.csv")["0"])
SS_SBUX_us                = list(pd.read_csv("./pairs/SS_SBUX_us.csv")["0"])
SS_SBUX_tse               = list(pd.read_csv("./pairs/SS_SBUX_tse.csv")["0"])
SS_SBUX_sse               = list(pd.read_csv("./pairs/SS_SBUX_sse.csv")["0"])
SS_SBUX_szse              = list(pd.read_csv("./pairs/SS_SBUX_szse.csv")["0"])
SS_SBUX_corr1_us          = list(pd.read_csv("./pairs/SS_SBUX_corr1_us.csv")["0"])
SS_SBUX_corr1_tse =         list(pd.read_csv("./pairs/SS_SBUX_corr1_tse.csv")["0"])
SS_SBUX_corr1_sse =         list(pd.read_csv("./pairs/SS_SBUX_corr1_sse.csv")["0"])
SS_SBUX_corr1_szse =        list(pd.read_csv("./pairs/SS_SBUX_corr1_szse.csv")["0"])
SS_SBUX_corr2_us =          list(pd.read_csv("./pairs/SS_SBUX_corr2_us.csv")["0"])
SS_SBUX_corr2_tse =         list(pd.read_csv("./pairs/SS_SBUX_corr2_tse.csv")["0"])
SS_SBUX_corr2_sse =         list(pd.read_csv("./pairs/SS_SBUX_corr2_sse.csv")["0"])
SS_SBUX_corr2_szse =        list(pd.read_csv("./pairs/SS_SBUX_corr2_szse.csv")["0"])


TS_NKE_us                = list(pd.read_csv("./pairs/TS_NKE_us.csv")["0"])
TS_NKE_tse               = list(pd.read_csv("./pairs/TS_NKE_tse.csv")["0"])
TS_NKE_sse               = list(pd.read_csv("./pairs/TS_NKE_sse.csv")["0"])
TS_NKE_szse              = list(pd.read_csv("./pairs/TS_NKE_szse.csv")["0"])
SS_NKE_us                = list(pd.read_csv("./pairs/SS_NKE_us.csv")["0"])
SS_NKE_tse               = list(pd.read_csv("./pairs/SS_NKE_tse.csv")["0"])
SS_NKE_sse               = list(pd.read_csv("./pairs/SS_NKE_sse.csv")["0"])
SS_NKE_szse              = list(pd.read_csv("./pairs/SS_NKE_szse.csv")["0"])
SS_NKE_corr1_us          = list(pd.read_csv("./pairs/SS_NKE_corr1_us.csv")["0"])
SS_NKE_corr1_tse =         list(pd.read_csv("./pairs/SS_NKE_corr1_tse.csv")["0"])
SS_NKE_corr1_sse =         list(pd.read_csv("./pairs/SS_NKE_corr1_sse.csv")["0"])
SS_NKE_corr1_szse =        list(pd.read_csv("./pairs/SS_NKE_corr1_szse.csv")["0"])
SS_NKE_corr2_us =          list(pd.read_csv("./pairs/SS_NKE_corr2_us.csv")["0"])
SS_NKE_corr2_tse =         list(pd.read_csv("./pairs/SS_NKE_corr2_tse.csv")["0"])
SS_NKE_corr2_sse =         list(pd.read_csv("./pairs/SS_NKE_corr2_sse.csv")["0"])
SS_NKE_corr2_szse =        list(pd.read_csv("./pairs/SS_NKE_corr2_szse.csv")["0"])


TS_MSFT_us                = list(pd.read_csv("./pairs/TS_MSFT_us.csv")["0"])
TS_MSFT_tse               = list(pd.read_csv("./pairs/TS_MSFT_tse.csv")["0"])
TS_MSFT_sse               = list(pd.read_csv("./pairs/TS_MSFT_sse.csv")["0"])
TS_MSFT_szse              = list(pd.read_csv("./pairs/TS_MSFT_szse.csv")["0"])
SS_MSFT_us                = list(pd.read_csv("./pairs/SS_MSFT_us.csv")["0"])
SS_MSFT_tse               = list(pd.read_csv("./pairs/SS_MSFT_tse.csv")["0"])
SS_MSFT_sse               = list(pd.read_csv("./pairs/SS_MSFT_sse.csv")["0"])
SS_MSFT_szse              = list(pd.read_csv("./pairs/SS_MSFT_szse.csv")["0"])
SS_MSFT_corr1_us          = list(pd.read_csv("./pairs/SS_MSFT_corr1_us.csv")["0"])
SS_MSFT_corr1_tse =         list(pd.read_csv("./pairs/SS_MSFT_corr1_tse.csv")["0"])
SS_MSFT_corr1_sse =         list(pd.read_csv("./pairs/SS_MSFT_corr1_sse.csv")["0"])
SS_MSFT_corr1_szse =        list(pd.read_csv("./pairs/SS_MSFT_corr1_szse.csv")["0"])
SS_MSFT_corr2_us =          list(pd.read_csv("./pairs/SS_MSFT_corr2_us.csv")["0"])
SS_MSFT_corr2_tse =         list(pd.read_csv("./pairs/SS_MSFT_corr2_tse.csv")["0"])
SS_MSFT_corr2_sse =         list(pd.read_csv("./pairs/SS_MSFT_corr2_sse.csv")["0"])
SS_MSFT_corr2_szse =        list(pd.read_csv("./pairs/SS_MSFT_corr2_szse.csv")["0"])

TS_NVDA_us                = list(pd.read_csv("./pairs/TS_NVDA_us.csv")["0"])
TS_NVDA_tse               = list(pd.read_csv("./pairs/TS_NVDA_tse.csv")["0"])
TS_NVDA_sse               = list(pd.read_csv("./pairs/TS_NVDA_sse.csv")["0"])
TS_NVDA_szse              = list(pd.read_csv("./pairs/TS_NVDA_szse.csv")["0"])
SS_NVDA_us                = list(pd.read_csv("./pairs/SS_NVDA_us.csv")["0"])
SS_NVDA_tse               = list(pd.read_csv("./pairs/SS_NVDA_tse.csv")["0"])
SS_NVDA_sse               = list(pd.read_csv("./pairs/SS_NVDA_sse.csv")["0"])
SS_NVDA_szse              = list(pd.read_csv("./pairs/SS_NVDA_szse.csv")["0"])
SS_NVDA_corr1_us          = list(pd.read_csv("./pairs/SS_NVDA_corr1_us.csv")["0"])
SS_NVDA_corr1_tse =         list(pd.read_csv("./pairs/SS_NVDA_corr1_tse.csv")["0"])
SS_NVDA_corr1_sse =         list(pd.read_csv("./pairs/SS_NVDA_corr1_sse.csv")["0"])
SS_NVDA_corr1_szse =        list(pd.read_csv("./pairs/SS_NVDA_corr1_szse.csv")["0"])
SS_NVDA_corr2_us =          list(pd.read_csv("./pairs/SS_NVDA_corr2_us.csv")["0"])
SS_NVDA_corr2_tse =         list(pd.read_csv("./pairs/SS_NVDA_corr2_tse.csv")["0"])
SS_NVDA_corr2_sse =         list(pd.read_csv("./pairs/SS_NVDA_corr2_sse.csv")["0"])
SS_NVDA_corr2_szse =        list(pd.read_csv("./pairs/SS_NVDA_corr2_szse.csv")["0"])

TS_NFLX_us                = list(pd.read_csv("./pairs/TS_NFLX_us.csv")["0"])
TS_NFLX_tse               = list(pd.read_csv("./pairs/TS_NFLX_tse.csv")["0"])
TS_NFLX_sse               = list(pd.read_csv("./pairs/TS_NFLX_sse.csv")["0"])
TS_NFLX_szse              = list(pd.read_csv("./pairs/TS_NFLX_szse.csv")["0"])
SS_NFLX_us                = list(pd.read_csv("./pairs/SS_NFLX_us.csv")["0"])
SS_NFLX_tse               = list(pd.read_csv("./pairs/SS_NFLX_tse.csv")["0"])
SS_NFLX_sse               = list(pd.read_csv("./pairs/SS_NFLX_sse.csv")["0"])
SS_NFLX_szse              = list(pd.read_csv("./pairs/SS_NFLX_szse.csv")["0"])
SS_NFLX_corr1_us          = list(pd.read_csv("./pairs/SS_NFLX_corr1_us.csv")["0"])
SS_NFLX_corr1_tse =         list(pd.read_csv("./pairs/SS_NFLX_corr1_tse.csv")["0"])
SS_NFLX_corr1_sse =         list(pd.read_csv("./pairs/SS_NFLX_corr1_sse.csv")["0"])
SS_NFLX_corr1_szse =        list(pd.read_csv("./pairs/SS_NFLX_corr1_szse.csv")["0"])
SS_NFLX_corr2_us =          list(pd.read_csv("./pairs/SS_NFLX_corr2_us.csv")["0"])
SS_NFLX_corr2_tse =         list(pd.read_csv("./pairs/SS_NFLX_corr2_tse.csv")["0"])
SS_NFLX_corr2_sse =         list(pd.read_csv("./pairs/SS_NFLX_corr2_sse.csv")["0"])
SS_NFLX_corr2_szse =        list(pd.read_csv("./pairs/SS_NFLX_corr2_szse.csv")["0"])

TS_T_us                = list(pd.read_csv("./pairs/TS_T_us.csv")["0"])
TS_T_tse               = list(pd.read_csv("./pairs/TS_T_tse.csv")["0"])
TS_T_sse               = list(pd.read_csv("./pairs/TS_T_sse.csv")["0"])
TS_T_szse              = list(pd.read_csv("./pairs/TS_T_szse.csv")["0"])
SS_T_us                = list(pd.read_csv("./pairs/SS_T_us.csv")["0"])
SS_T_tse               = list(pd.read_csv("./pairs/SS_T_tse.csv")["0"])
SS_T_sse               = list(pd.read_csv("./pairs/SS_T_sse.csv")["0"])
SS_T_szse              = list(pd.read_csv("./pairs/SS_T_szse.csv")["0"])
SS_T_corr1_us          = list(pd.read_csv("./pairs/SS_T_corr1_us.csv")["0"])
SS_T_corr1_tse =         list(pd.read_csv("./pairs/SS_T_corr1_tse.csv")["0"])
SS_T_corr1_sse =         list(pd.read_csv("./pairs/SS_T_corr1_sse.csv")["0"])
SS_T_corr1_szse =        list(pd.read_csv("./pairs/SS_T_corr1_szse.csv")["0"])
SS_T_corr2_us =          list(pd.read_csv("./pairs/SS_T_corr2_us.csv")["0"])
SS_T_corr2_tse =         list(pd.read_csv("./pairs/SS_T_corr2_tse.csv")["0"])
SS_T_corr2_sse =         list(pd.read_csv("./pairs/SS_T_corr2_sse.csv")["0"])
SS_T_corr2_szse =        list(pd.read_csv("./pairs/SS_T_corr2_szse.csv")["0"])


TS_MA_us                = list(pd.read_csv("./pairs/TS_MA_us.csv")["0"])
TS_MA_tse               = list(pd.read_csv("./pairs/TS_MA_tse.csv")["0"])
TS_MA_sse               = list(pd.read_csv("./pairs/TS_MA_sse.csv")["0"])
TS_MA_szse              = list(pd.read_csv("./pairs/TS_MA_szse.csv")["0"])
SS_MA_us                = list(pd.read_csv("./pairs/SS_MA_us.csv")["0"])
SS_MA_tse               = list(pd.read_csv("./pairs/SS_MA_tse.csv")["0"])
SS_MA_sse               = list(pd.read_csv("./pairs/SS_MA_sse.csv")["0"])
SS_MA_szse              = list(pd.read_csv("./pairs/SS_MA_szse.csv")["0"])
SS_MA_corr1_us          = list(pd.read_csv("./pairs/SS_MA_corr1_us.csv")["0"])
SS_MA_corr1_tse =         list(pd.read_csv("./pairs/SS_MA_corr1_tse.csv")["0"])
SS_MA_corr1_sse =         list(pd.read_csv("./pairs/SS_MA_corr1_sse.csv")["0"])
SS_MA_corr1_szse =        list(pd.read_csv("./pairs/SS_MA_corr1_szse.csv")["0"])
SS_MA_corr2_us =          list(pd.read_csv("./pairs/SS_MA_corr2_us.csv")["0"])
SS_MA_corr2_tse =         list(pd.read_csv("./pairs/SS_MA_corr2_tse.csv")["0"])
SS_MA_corr2_sse =         list(pd.read_csv("./pairs/SS_MA_corr2_sse.csv")["0"])
SS_MA_corr2_szse =        list(pd.read_csv("./pairs/SS_MA_corr2_szse.csv")["0"])

TS_WMT_us                = list(pd.read_csv("./pairs/TS_WMT_us.csv")["0"])
TS_WMT_tse               = list(pd.read_csv("./pairs/TS_WMT_tse.csv")["0"])
TS_WMT_sse               = list(pd.read_csv("./pairs/TS_WMT_sse.csv")["0"])
TS_WMT_szse              = list(pd.read_csv("./pairs/TS_WMT_szse.csv")["0"])
SS_WMT_us                = list(pd.read_csv("./pairs/SS_WMT_us.csv")["0"])
SS_WMT_tse               = list(pd.read_csv("./pairs/SS_WMT_tse.csv")["0"])
SS_WMT_sse               = list(pd.read_csv("./pairs/SS_WMT_sse.csv")["0"])
SS_WMT_szse              = list(pd.read_csv("./pairs/SS_WMT_szse.csv")["0"])
SS_WMT_corr1_us          = list(pd.read_csv("./pairs/SS_WMT_corr1_us.csv")["0"])
SS_WMT_corr1_tse =         list(pd.read_csv("./pairs/SS_WMT_corr1_tse.csv")["0"])
SS_WMT_corr1_sse =         list(pd.read_csv("./pairs/SS_WMT_corr1_sse.csv")["0"])
SS_WMT_corr1_szse =        list(pd.read_csv("./pairs/SS_WMT_corr1_szse.csv")["0"])
SS_WMT_corr2_us =          list(pd.read_csv("./pairs/SS_WMT_corr2_us.csv")["0"])
SS_WMT_corr2_tse =         list(pd.read_csv("./pairs/SS_WMT_corr2_tse.csv")["0"])
SS_WMT_corr2_sse =         list(pd.read_csv("./pairs/SS_WMT_corr2_sse.csv")["0"])
SS_WMT_corr2_szse =        list(pd.read_csv("./pairs/SS_WMT_corr2_szse.csv")["0"])

TS_BA_us                = list(pd.read_csv("./pairs/TS_BA_us.csv")["0"])
TS_BA_tse               = list(pd.read_csv("./pairs/TS_BA_tse.csv")["0"])
TS_BA_sse               = list(pd.read_csv("./pairs/TS_BA_sse.csv")["0"])
TS_BA_szse              = list(pd.read_csv("./pairs/TS_BA_szse.csv")["0"])
SS_BA_us                = list(pd.read_csv("./pairs/SS_BA_us.csv")["0"])
SS_BA_tse               = list(pd.read_csv("./pairs/SS_BA_tse.csv")["0"])
SS_BA_sse               = list(pd.read_csv("./pairs/SS_BA_sse.csv")["0"])
SS_BA_szse              = list(pd.read_csv("./pairs/SS_BA_szse.csv")["0"])
SS_BA_corr1_us          = list(pd.read_csv("./pairs/SS_BA_corr1_us.csv")["0"])
SS_BA_corr1_tse =         list(pd.read_csv("./pairs/SS_BA_corr1_tse.csv")["0"])
SS_BA_corr1_sse =         list(pd.read_csv("./pairs/SS_BA_corr1_sse.csv")["0"])
SS_BA_corr1_szse =        list(pd.read_csv("./pairs/SS_BA_corr1_szse.csv")["0"])
SS_BA_corr2_us =          list(pd.read_csv("./pairs/SS_BA_corr2_us.csv")["0"])
SS_BA_corr2_tse =         list(pd.read_csv("./pairs/SS_BA_corr2_tse.csv")["0"])
SS_BA_corr2_sse =         list(pd.read_csv("./pairs/SS_BA_corr2_sse.csv")["0"])
SS_BA_corr2_szse =        list(pd.read_csv("./pairs/SS_BA_corr2_szse.csv")["0"])

TS_AAPL_us                = list(pd.read_csv("./pairs/TS_AAPL_us.csv")["0"])
TS_AAPL_tse               = list(pd.read_csv("./pairs/TS_AAPL_tse.csv")["0"])
TS_AAPL_sse               = list(pd.read_csv("./pairs/TS_AAPL_sse.csv")["0"])
TS_AAPL_szse              = list(pd.read_csv("./pairs/TS_AAPL_szse.csv")["0"])
SS_AAPL_us                = list(pd.read_csv("./pairs/SS_AAPL_us.csv")["0"])
SS_AAPL_tse               = list(pd.read_csv("./pairs/SS_AAPL_tse.csv")["0"])
SS_AAPL_sse               = list(pd.read_csv("./pairs/SS_AAPL_sse.csv")["0"])
SS_AAPL_szse              = list(pd.read_csv("./pairs/SS_AAPL_szse.csv")["0"])
SS_AAPL_corr1_us          = list(pd.read_csv("./pairs/SS_AAPL_corr1_us.csv")["0"])
SS_AAPL_corr1_tse =         list(pd.read_csv("./pairs/SS_AAPL_corr1_tse.csv")["0"])
SS_AAPL_corr1_sse =         list(pd.read_csv("./pairs/SS_AAPL_corr1_sse.csv")["0"])
SS_AAPL_corr1_szse =        list(pd.read_csv("./pairs/SS_AAPL_corr1_szse.csv")["0"])
SS_AAPL_corr2_us =          list(pd.read_csv("./pairs/SS_AAPL_corr2_us.csv")["0"])
SS_AAPL_corr2_tse =         list(pd.read_csv("./pairs/SS_AAPL_corr2_tse.csv")["0"])
SS_AAPL_corr2_sse =         list(pd.read_csv("./pairs/SS_AAPL_corr2_sse.csv")["0"])
SS_AAPL_corr2_szse =        list(pd.read_csv("./pairs/SS_AAPL_corr2_szse.csv")["0"])

TS_XOM_us                = list(pd.read_csv("./pairs/TS_XOM_us.csv")["0"])
TS_XOM_tse               = list(pd.read_csv("./pairs/TS_XOM_tse.csv")["0"])
TS_XOM_sse               = list(pd.read_csv("./pairs/TS_XOM_sse.csv")["0"])
TS_XOM_szse              = list(pd.read_csv("./pairs/TS_XOM_szse.csv")["0"])
SS_XOM_us                = list(pd.read_csv("./pairs/SS_XOM_us.csv")["0"])
SS_XOM_tse               = list(pd.read_csv("./pairs/SS_XOM_tse.csv")["0"])
SS_XOM_sse               = list(pd.read_csv("./pairs/SS_XOM_sse.csv")["0"])
SS_XOM_szse              = list(pd.read_csv("./pairs/SS_XOM_szse.csv")["0"])
SS_XOM_corr1_us          = list(pd.read_csv("./pairs/SS_XOM_corr1_us.csv")["0"])
SS_XOM_corr1_tse =         list(pd.read_csv("./pairs/SS_XOM_corr1_tse.csv")["0"])
SS_XOM_corr1_sse =         list(pd.read_csv("./pairs/SS_XOM_corr1_sse.csv")["0"])
SS_XOM_corr1_szse =        list(pd.read_csv("./pairs/SS_XOM_corr1_szse.csv")["0"])
SS_XOM_corr2_us =          list(pd.read_csv("./pairs/SS_XOM_corr2_us.csv")["0"])
SS_XOM_corr2_tse =         list(pd.read_csv("./pairs/SS_XOM_corr2_tse.csv")["0"])
SS_XOM_corr2_sse =         list(pd.read_csv("./pairs/SS_XOM_corr2_sse.csv")["0"])
SS_XOM_corr2_szse =        list(pd.read_csv("./pairs/SS_XOM_corr2_szse.csv")["0"])


TS_AMZN_us                = list(pd.read_csv("./pairs/TS_AMZN_us.csv")["0"])
TS_AMZN_tse               = list(pd.read_csv("./pairs/TS_AMZN_tse.csv")["0"])
TS_AMZN_sse               = list(pd.read_csv("./pairs/TS_AMZN_sse.csv")["0"])
TS_AMZN_szse              = list(pd.read_csv("./pairs/TS_AMZN_szse.csv")["0"])
SS_AMZN_us                = list(pd.read_csv("./pairs/SS_AMZN_us.csv")["0"])
SS_AMZN_tse               = list(pd.read_csv("./pairs/SS_AMZN_tse.csv")["0"])
SS_AMZN_sse               = list(pd.read_csv("./pairs/SS_AMZN_sse.csv")["0"])
SS_AMZN_szse              = list(pd.read_csv("./pairs/SS_AMZN_szse.csv")["0"])
SS_AMZN_corr1_us          = list(pd.read_csv("./pairs/SS_AMZN_corr1_us.csv")["0"])
SS_AMZN_corr1_tse =         list(pd.read_csv("./pairs/SS_AMZN_corr1_tse.csv")["0"])
SS_AMZN_corr1_sse =         list(pd.read_csv("./pairs/SS_AMZN_corr1_sse.csv")["0"])
SS_AMZN_corr1_szse =        list(pd.read_csv("./pairs/SS_AMZN_corr1_szse.csv")["0"])
SS_AMZN_corr2_us =          list(pd.read_csv("./pairs/SS_AMZN_corr2_us.csv")["0"])
SS_AMZN_corr2_tse =         list(pd.read_csv("./pairs/SS_AMZN_corr2_tse.csv")["0"])
SS_AMZN_corr2_sse =         list(pd.read_csv("./pairs/SS_AMZN_corr2_sse.csv")["0"])
SS_AMZN_corr2_szse =        list(pd.read_csv("./pairs/SS_AMZN_corr2_szse.csv")["0"])


TS_CMG_us                = list(pd.read_csv("./pairs/TS_CMG_us.csv")["0"])
TS_CMG_tse               = list(pd.read_csv("./pairs/TS_CMG_tse.csv")["0"])
TS_CMG_sse               = list(pd.read_csv("./pairs/TS_CMG_sse.csv")["0"])
TS_CMG_szse              = list(pd.read_csv("./pairs/TS_CMG_szse.csv")["0"])
SS_CMG_us                = list(pd.read_csv("./pairs/SS_CMG_us.csv")["0"])
SS_CMG_tse               = list(pd.read_csv("./pairs/SS_CMG_tse.csv")["0"])
SS_CMG_sse               = list(pd.read_csv("./pairs/SS_CMG_sse.csv")["0"])
SS_CMG_szse              = list(pd.read_csv("./pairs/SS_CMG_szse.csv")["0"])
SS_CMG_corr1_us          = list(pd.read_csv("./pairs/SS_CMG_corr1_us.csv")["0"])
SS_CMG_corr1_tse =         list(pd.read_csv("./pairs/SS_CMG_corr1_tse.csv")["0"])
SS_CMG_corr1_sse =         list(pd.read_csv("./pairs/SS_CMG_corr1_sse.csv")["0"])
SS_CMG_corr1_szse =        list(pd.read_csv("./pairs/SS_CMG_corr1_szse.csv")["0"])
SS_CMG_corr2_us =          list(pd.read_csv("./pairs/SS_CMG_corr2_us.csv")["0"])
SS_CMG_corr2_tse =         list(pd.read_csv("./pairs/SS_CMG_corr2_tse.csv")["0"])
SS_CMG_corr2_sse =         list(pd.read_csv("./pairs/SS_CMG_corr2_sse.csv")["0"])
SS_CMG_corr2_szse =        list(pd.read_csv("./pairs/SS_CMG_corr2_szse.csv")["0"])

TS_LRCX_us                = list(pd.read_csv("./pairs/TS_LRCX_us.csv")["0"])
TS_LRCX_tse               = list(pd.read_csv("./pairs/TS_LRCX_tse.csv")["0"])
TS_LRCX_sse               = list(pd.read_csv("./pairs/TS_LRCX_sse.csv")["0"])
TS_LRCX_szse              = list(pd.read_csv("./pairs/TS_LRCX_szse.csv")["0"])
SS_LRCX_us                = list(pd.read_csv("./pairs/SS_LRCX_us.csv")["0"])
SS_LRCX_tse               = list(pd.read_csv("./pairs/SS_LRCX_tse.csv")["0"])
SS_LRCX_sse               = list(pd.read_csv("./pairs/SS_LRCX_sse.csv")["0"])
SS_LRCX_szse              = list(pd.read_csv("./pairs/SS_LRCX_szse.csv")["0"])
SS_LRCX_corr1_us          = list(pd.read_csv("./pairs/SS_LRCX_corr1_us.csv")["0"])
SS_LRCX_corr1_tse =         list(pd.read_csv("./pairs/SS_LRCX_corr1_tse.csv")["0"])
SS_LRCX_corr1_sse =         list(pd.read_csv("./pairs/SS_LRCX_corr1_sse.csv")["0"])
SS_LRCX_corr1_szse =        list(pd.read_csv("./pairs/SS_LRCX_corr1_szse.csv")["0"])
SS_LRCX_corr2_us =          list(pd.read_csv("./pairs/SS_LRCX_corr2_us.csv")["0"])
SS_LRCX_corr2_tse =         list(pd.read_csv("./pairs/SS_LRCX_corr2_tse.csv")["0"])
SS_LRCX_corr2_sse =         list(pd.read_csv("./pairs/SS_LRCX_corr2_sse.csv")["0"])
SS_LRCX_corr2_szse =        list(pd.read_csv("./pairs/SS_LRCX_corr2_szse.csv")["0"])

TS_CVS_us                = list(pd.read_csv("./pairs/TS_CVS_us.csv")["0"])
TS_CVS_tse               = list(pd.read_csv("./pairs/TS_CVS_tse.csv")["0"])
TS_CVS_sse               = list(pd.read_csv("./pairs/TS_CVS_sse.csv")["0"])
TS_CVS_szse              = list(pd.read_csv("./pairs/TS_CVS_szse.csv")["0"])
SS_CVS_us                = list(pd.read_csv("./pairs/SS_CVS_us.csv")["0"])
SS_CVS_tse               = list(pd.read_csv("./pairs/SS_CVS_tse.csv")["0"])
SS_CVS_sse               = list(pd.read_csv("./pairs/SS_CVS_sse.csv")["0"])
SS_CVS_szse              = list(pd.read_csv("./pairs/SS_CVS_szse.csv")["0"])
SS_CVS_corr1_us          = list(pd.read_csv("./pairs/SS_CVS_corr1_us.csv")["0"])
SS_CVS_corr1_tse =         list(pd.read_csv("./pairs/SS_CVS_corr1_tse.csv")["0"])
SS_CVS_corr1_sse =         list(pd.read_csv("./pairs/SS_CVS_corr1_sse.csv")["0"])
SS_CVS_corr1_szse =        list(pd.read_csv("./pairs/SS_CVS_corr1_szse.csv")["0"])
SS_CVS_corr2_us =          list(pd.read_csv("./pairs/SS_CVS_corr2_us.csv")["0"])
SS_CVS_corr2_tse =         list(pd.read_csv("./pairs/SS_CVS_corr2_tse.csv")["0"])
SS_CVS_corr2_sse =         list(pd.read_csv("./pairs/SS_CVS_corr2_sse.csv")["0"])
SS_CVS_corr2_szse =        list(pd.read_csv("./pairs/SS_CVS_corr2_szse.csv")["0"])

# %%
cmg_r, cmg_s = all_run_pair_top_exchange(SS_CMG_us      ,SS_CMG_sse      ,  SS_CMG_szse      ,  SS_CMG_tse,             
                                         TS_CMG_us      ,TS_CMG_sse      ,  TS_CMG_szse      ,  TS_CMG_tse ,     
                                         SS_CMG_corr1_us,SS_CMG_corr1_sse,  SS_CMG_corr1_szse,  SS_CMG_corr1_tse,
                                         SS_CMG_corr2_us,SS_CMG_corr2_sse,  SS_CMG_corr2_szse,  SS_CMG_corr2_tse,  "2022-01-01", "2023-01-01", 500)

# %%
aapl_r, aapl_s = all_run_pair_top_exchange(SS_AAPL_us      ,SS_AAPL_sse      ,  SS_AAPL_szse      ,  SS_AAPL_tse,             
                                         TS_AAPL_us      ,TS_AAPL_sse      ,  TS_AAPL_szse      ,  TS_AAPL_tse ,     
                                         SS_AAPL_corr1_us,SS_AAPL_corr1_sse,  SS_AAPL_corr1_szse,  SS_AAPL_corr1_tse,
                                         SS_AAPL_corr2_us,SS_AAPL_corr2_sse,  SS_AAPL_corr2_szse,  SS_AAPL_corr2_tse,  "2022-01-01", "2023-01-01", 500)

# %%
msft_r, msft_s = all_run_pair_top_exchange(SS_MSFT_us      ,SS_MSFT_sse      ,  SS_MSFT_szse      ,  SS_MSFT_tse,             
                                         TS_MSFT_us      ,TS_MSFT_sse      ,  TS_MSFT_szse      ,  TS_MSFT_tse ,     
                                         SS_MSFT_corr1_us,SS_MSFT_corr1_sse,  SS_MSFT_corr1_szse,  SS_MSFT_corr1_tse,
                                         SS_MSFT_corr2_us,SS_MSFT_corr2_sse,  SS_MSFT_corr2_szse,  SS_MSFT_corr2_tse,  "2022-01-01", "2023-01-01", 500)

# %%
nflx_r, mflx_s = all_run_pair_top_exchange(SS_NFLX_us      ,SS_NFLX_sse      ,  SS_NFLX_szse      ,  SS_NFLX_tse,             
                                         TS_NFLX_us      ,TS_NFLX_sse      ,  TS_NFLX_szse      ,  TS_NFLX_tse ,     
                                         SS_NFLX_corr1_us,SS_NFLX_corr1_sse,  SS_NFLX_corr1_szse,  SS_NFLX_corr1_tse,
                                         SS_NFLX_corr2_us,SS_NFLX_corr2_sse,  SS_NFLX_corr2_szse,  SS_NFLX_corr2_tse,  "2022-01-01", "2023-01-01", 500)

# %%
nvda_r, nvda_s = all_run_pair_top_exchange(SS_NVDA_us      ,SS_NVDA_sse      ,  SS_NVDA_szse      ,  SS_NVDA_tse,             
                                           TS_NVDA_us      ,TS_NVDA_sse      ,  TS_NVDA_szse      ,  TS_NVDA_tse ,     
                                           SS_NVDA_corr1_us,SS_NVDA_corr1_sse,  SS_NVDA_corr1_szse,  SS_NVDA_corr1_tse,
                                           SS_NVDA_corr2_us,SS_NVDA_corr2_sse,  SS_NVDA_corr2_szse,  SS_NVDA_corr2_tse,  "2022-01-01", "2023-01-01", 500)

# %%
xom_r, xom_s = all_run_pair_top_exchange(SS_XOM_us      ,SS_XOM_sse      ,  SS_XOM_szse      ,  SS_XOM_tse,             
                                         TS_XOM_us      ,TS_XOM_sse      ,  TS_XOM_szse      ,  TS_XOM_tse ,     
                                         SS_XOM_corr1_us,SS_XOM_corr1_sse,  SS_XOM_corr1_szse,  SS_XOM_corr1_tse,
                                         SS_XOM_corr2_us,SS_XOM_corr2_sse,  SS_XOM_corr2_szse,  SS_XOM_corr2_tse,  "2022-01-01", "2023-01-01", 500)

# %%
pfe_r, pfe_s = all_run_pair_top_exchange(SS_PFE_us      ,SS_PFE_sse      ,  SS_PFE_szse      ,  SS_PFE_tse,             
                                     TS_PFE_us      ,TS_PFE_sse      ,  TS_PFE_szse      ,  TS_PFE_tse ,     
                                     SS_PFE_corr1_us,SS_PFE_corr1_sse,  SS_PFE_corr1_szse,  SS_PFE_corr1_tse,
                                     SS_PFE_corr2_us,SS_PFE_corr2_sse,  SS_PFE_corr2_szse,  SS_PFE_corr2_tse,  "2022-01-01", "2023-01-01", 500)

# %%
amzn_r, amzn_s = all_run_pair_top_exchange(SS_AMZN_us      ,SS_AMZN_sse      ,  SS_AMZN_szse      ,  SS_AMZN_tse,             
                                         TS_AMZN_us      ,TS_AMZN_sse      ,  TS_AMZN_szse      ,  TS_AMZN_tse ,     
                                         SS_AMZN_corr1_us,SS_AMZN_corr1_sse,  SS_AMZN_corr1_szse,  SS_AMZN_corr1_tse,
                                         SS_AMZN_corr2_us,SS_AMZN_corr2_sse,  SS_AMZN_corr2_szse,  SS_AMZN_corr2_tse,  "2022-01-01", "2023-01-01", 500)

# %%
ba_r, ba_s = all_run_pair_top_exchange(SS_BA_us      ,SS_BA_sse      ,  SS_BA_szse      ,  SS_BA_tse,             
                                         TS_BA_us      ,TS_BA_sse      ,  TS_BA_szse      ,  TS_BA_tse ,     
                                         SS_BA_corr1_us,SS_BA_corr1_sse,  SS_BA_corr1_szse,  SS_BA_corr1_tse,
                                         SS_BA_corr2_us,SS_BA_corr2_sse,  SS_BA_corr2_szse,  SS_BA_corr2_tse,  "2022-01-01", "2023-01-01", 500)

# %%
nke_r, nke_s = all_run_pair_top_exchange(SS_NKE_us      ,SS_NKE_sse      ,  SS_NKE_szse      ,  SS_NKE_tse,             
                                         TS_NKE_us      ,TS_NKE_sse      ,  TS_NKE_szse      ,  TS_NKE_tse ,     
                                         SS_NKE_corr1_us,SS_NKE_corr1_sse,  SS_NKE_corr1_szse,  SS_NKE_corr1_tse,
                                         SS_NKE_corr2_us,SS_NKE_corr2_sse,  SS_NKE_corr2_szse,  SS_NKE_corr2_tse,  "2022-01-01", "2023-01-01", 500)

# %%
ma_r, ma_s = all_run_pair_top_exchange(SS_MA_us      ,SS_MA_sse      ,  SS_MA_szse      ,  SS_MA_tse,             
                                         TS_MA_us      ,TS_MA_sse      ,  TS_MA_szse      ,  TS_MA_tse ,     
                                         SS_MA_corr1_us,SS_MA_corr1_sse,  SS_MA_corr1_szse,  SS_MA_corr1_tse,
                                         SS_MA_corr2_us,SS_MA_corr2_sse,  SS_MA_corr2_szse,  SS_MA_corr2_tse,  "2022-01-01", "2023-01-01", 500)

# %%
cvs_r, cvs_s = all_run_pair_top_exchange(SS_CVS_us      ,SS_CVS_sse      ,  SS_CVS_szse      ,  SS_CVS_tse,             
                                         TS_CVS_us      ,TS_CVS_sse      ,  TS_CVS_szse      ,  TS_CVS_tse ,     
                                         SS_CVS_corr1_us,SS_CVS_corr1_sse,  SS_CVS_corr1_szse,  SS_CVS_corr1_tse,
                                         SS_CVS_corr2_us,SS_CVS_corr2_sse,  SS_CVS_corr2_szse,  SS_CVS_corr2_tse,  "2022-01-01", "2023-01-01", 500)

# %%
def get_stat(stat_data, ex):
    #ex == 0 : us ex ==1 sse ex==2 szse else tse
    
    mean_=pd.concat([stat_data[ex][0][0].round(3) , 
                     stat_data[ex][1][0].round(3) ,
                     stat_data[ex][2][0].round(3) ], axis = 1)
    
    std_= pd.concat([stat_data[ex][0][1].round(3) , 
                     stat_data[ex][1][1].round(3) ,
                     stat_data[ex][2][1].round(3) ], axis = 1)
    
    max_ =pd.concat([stat_data[ex][0][2].round(3) , 
                     stat_data[ex][1][2].round(3) ,
                     stat_data[ex][2][2].round(3) ], axis = 1)
    
    min_ =pd.concat([stat_data[ex][0][3].round(3) , 
                     stat_data[ex][1][3].round(3) ,
                     stat_data[ex][2][3].round(3) ], axis = 1)
    
    return mean_, std_, max_, min_

# %%
wealth = pd.concat([
           get_stat(aapl_s,   0)[0].iloc[2:, :],   
           get_stat(cmg_s,    0)[0].iloc[2:, :],   
           get_stat(msft_s,   0)[0].iloc[2:, :],    
           get_stat(mflx_s,   0)[0].iloc[2:, :],
           get_stat(nvda_s,   0)[0].iloc[2:, :],  
           get_stat(xom_s,    0)[0].iloc[2:, :],   
           get_stat(pfe_s,    0)[0].iloc[2:, :],   
           get_stat(amzn_s,   0)[0].iloc[2:, :],  
           get_stat(ba_s,     0)[0].iloc[2:, :],     
           get_stat(nke_s,    0)[0].iloc[2:, :],
           get_stat(ma_s,     0)[0].iloc[2:, :],
           get_stat(cvs_s,    0)[0].iloc[2:, :],   
          ]).iloc[:,4:8]

wealth_std = pd.concat([
           get_stat(aapl_s,   0)[1].iloc[2:, :],   
           get_stat(cmg_s,    0)[1].iloc[2:, :],   
           get_stat(msft_s,   0)[1].iloc[2:, :],    
           get_stat(mflx_s,   0)[1].iloc[2:, :],
           get_stat(nvda_s,   0)[1].iloc[2:, :],  
           get_stat(xom_s,    0)[1].iloc[2:, :],   
           get_stat(pfe_s,    0)[1].iloc[2:, :],   
           get_stat(amzn_s,   0)[1].iloc[2:, :],  
           get_stat(ba_s,     0)[1].iloc[2:, :],     
           get_stat(nke_s,    0)[1].iloc[2:, :],
           get_stat(ma_s,     0)[1].iloc[2:, :],
           get_stat(cvs_s,    0)[1].iloc[2:, :],   
          ]).iloc[:,4:8]

mdd = pd.concat([
           get_stat(aapl_s,   0)[0].iloc[:1, :],   
           get_stat(cmg_s,    0)[0].iloc[:1, :],   
           get_stat(msft_s,   0)[0].iloc[:1, :],    
           get_stat(mflx_s,   0)[0].iloc[:1, :],
           get_stat(nvda_s,   0)[0].iloc[:1, :],  
           get_stat(xom_s,    0)[0].iloc[:1, :],   
           get_stat(pfe_s,    0)[0].iloc[:1, :],   
           get_stat(amzn_s,   0)[0].iloc[:1, :],  
           get_stat(ba_s,     0)[0].iloc[:1, :],     
           get_stat(nke_s,    0)[0].iloc[:1, :],
           get_stat(ma_s,     0)[0].iloc[:1, :],
           get_stat(cvs_s,    0)[0].iloc[:1, :],   
          ]).iloc[:,4:8]

mdd_std = pd.concat([
           get_stat(aapl_s,   0)[1].iloc[:1, :],   
           get_stat(cmg_s,    0)[1].iloc[:1, :],   
           get_stat(msft_s,   0)[1].iloc[:1, :],    
           get_stat(mflx_s,   0)[1].iloc[:1, :],
           get_stat(nvda_s,   0)[1].iloc[:1, :],  
           get_stat(xom_s,    0)[1].iloc[:1, :],   
           get_stat(pfe_s,    0)[1].iloc[:1, :],   
           get_stat(amzn_s,   0)[1].iloc[:1, :],  
           get_stat(ba_s,     0)[1].iloc[:1, :],     
           get_stat(nke_s,    0)[1].iloc[:1, :],
           get_stat(ma_s,     0)[1].iloc[:1, :],
           get_stat(cvs_s,    0)[1].iloc[:1, :],   
          ]).iloc[:,4:8]

# %%
wealth_df = wealth.round(2).astype(str)
wealth_std = ' \tiny{\pm' + wealth_std.round(2).astype(str) +"}"
wealth_df.columns = ["SS","TS","C1","C2"]
wealth_std.columns = ["SS","TS","C1","C2"]

# %%
(wealth_df + wealth_std)
# Out:
#                               SS                         TS  \
# Wealth   959.96 \tiny{\pm473.76}          nan \tiny{\pmnan}
# Wealth   545.81 \tiny{\pm722.54}    282.17 \tiny{\pm713.52}
# Wealth    754.51 \tiny{\pm70.99}    497.55 \tiny{\pm784.46}
# Wealth    561.8 \tiny{\pm169.84}  -777.72 \tiny{\pm1123.02}
# Wealth    354.24 \tiny{\pm116.6}     23.66 \tiny{\pm226.45}
# Wealth   403.26 \tiny{\pm265.92}    364.02 \tiny{\pm248.26}
# Wealth  -413.02 \tiny{\pm674.64}   113.17 \tiny{\pm2265.54}
# Wealth    120.9 \tiny{\pm244.16}   386.26 \tiny{\pm1304.23}
# Wealth  572.25 \tiny{\pm2255.81}       14.5 \tiny{\pm850.4}
# Wealth     1343.46 \tiny{\pmnan}  -597.33 \tiny{\pm1276.49}
# Wealth    123.06 \tiny{\pm66.54}     -98.5 \tiny{\pm267.16}
# Wealth  1101.66 \tiny{\pm536.96}    -618.2 \tiny{\pm753.38}
#
#                                C1                         C2
# Wealth   234.53 \tiny{\pm1164.22}    915.16 \tiny{\pm338.61}
# Wealth  -1069.02 \tiny{\pm721.61}  -1097.43 \tiny{\pm892.15}
# ...

# %%
mdd_df = (-mdd.round(2)).astype(str)
mdd_std = ' \tiny{\pm' + mdd_std.round(2).astype(str) +"}"
mdd_df.columns = ["SS","TS","C1","C2"]
mdd_std.columns = ["SS","TS","C1","C2"]

# %%
(mdd_df + mdd_std)
# Out:
#                                           SS                      TS  \
# Maximum Drawdown (%)    -1.91 \tiny{\pm0.67}       nan \tiny{\pmnan}
# Maximum Drawdown (%)    -2.98 \tiny{\pm2.54}    -6.37 \tiny{\pm2.22}
# Maximum Drawdown (%)    -3.79 \tiny{\pm0.21}    -5.66 \tiny{\pm0.24}
# Maximum Drawdown (%)     -2.2 \tiny{\pm3.77}    -9.16 \tiny{\pm8.29}
# Maximum Drawdown (%)    -2.22 \tiny{\pm2.55}    -2.38 \tiny{\pm2.77}
# Maximum Drawdown (%)    -3.38 \tiny{\pm0.44}    -3.02 \tiny{\pm2.95}
# Maximum Drawdown (%)    -7.84 \tiny{\pm7.41}  -10.03 \tiny{\pm13.49}
# Maximum Drawdown (%)    -5.05 \tiny{\pm4.99}    -4.67 \tiny{\pm2.33}
# Maximum Drawdown (%)  -12.09 \tiny{\pm11.57}    -5.87 \tiny{\pm2.13}
# Maximum Drawdown (%)     -4.91 \tiny{\pmnan}    -8.75 \tiny{\pm8.98}
# Maximum Drawdown (%)    -2.18 \tiny{\pm2.51}    -5.01 \tiny{\pm5.19}
# Maximum Drawdown (%)    -3.01 \tiny{\pm1.84}    -9.08 \tiny{\pm8.32}
#
#                                          C1                      C2
# ...

# %%
wealth = pd.concat([
           get_stat(aapl_s,   0)[0].iloc[2:, :],   
           get_stat(cmg_s,    0)[0].iloc[2:, :],   
           get_stat(msft_s,   0)[0].iloc[2:, :],    
           get_stat(mflx_s,   0)[0].iloc[2:, :],
           get_stat(nvda_s,   0)[0].iloc[2:, :],  
           get_stat(xom_s,    0)[0].iloc[2:, :],   
           get_stat(pfe_s,    0)[0].iloc[2:, :],   
           get_stat(amzn_s,   0)[0].iloc[2:, :],  
           get_stat(ba_s,     0)[0].iloc[2:, :],     
           get_stat(nke_s,    0)[0].iloc[2:, :],
           get_stat(ma_s,     0)[0].iloc[2:, :],
           get_stat(cvs_s,    0)[0].iloc[2:, :],   
          ]).iloc[:,8:]


mdd = pd.concat([
           get_stat(aapl_s,   0)[0].iloc[:1, :],   
           get_stat(cmg_s,    0)[0].iloc[:1, :],   
           get_stat(msft_s,   0)[0].iloc[:1, :],    
           get_stat(mflx_s,   0)[0].iloc[:1, :],
           get_stat(nvda_s,   0)[0].iloc[:1, :],  
           get_stat(xom_s,    0)[0].iloc[:1, :],   
           get_stat(pfe_s,    0)[0].iloc[:1, :],   
           get_stat(amzn_s,   0)[0].iloc[:1, :],  
           get_stat(ba_s,     0)[0].iloc[:1, :],     
           get_stat(nke_s,    0)[0].iloc[:1, :],
           get_stat(ma_s,     0)[0].iloc[:1, :],
           get_stat(cvs_s,    0)[0].iloc[:1, :],   
          ]).iloc[:,8:]

# %%
wealth.round(2)
# Out:
#         SS_1_mean  TS_1_mean  C1_1_mean  C2_1_mean
# Wealth    1506.88    1302.67    -797.21     766.51
# Wealth     372.84    -541.61   -1202.23   -1502.99
# Wealth     802.21    1275.91     847.28     509.61
# Wealth     751.44        NaN    1236.13     751.44
# Wealth     240.25     240.25     240.25     240.25
# Wealth     113.28     113.28    -192.12   -1147.63
# Wealth    -309.74        NaN     296.56    1499.64
# Wealth     372.84    1224.03   -1741.79     660.63
# Wealth    1320.62     117.68    -920.97     891.91
# Wealth     531.60   -2046.25    1617.05    1060.88
# Wealth     197.88     197.88     197.88     197.88
# Wealth     727.14   -1421.22    1486.60     438.36

# %%
-mdd.round(2)
# Out:
#                       SS_1_mean  TS_1_mean  C1_1_mean  C2_1_mean
# Maximum Drawdown (%)      -2.20      -2.11      -8.55      -5.70
# Maximum Drawdown (%)      -5.18      -8.53     -13.60     -21.10
# Maximum Drawdown (%)      -3.82      -5.41      -7.59      -5.89
# Maximum Drawdown (%)      -0.04        NaN      -0.78      -0.04
# Maximum Drawdown (%)      -0.00      -0.00      -0.00      -0.00
# Maximum Drawdown (%)      -3.07      -3.07      -5.47     -14.73
# Maximum Drawdown (%)      -7.48        NaN      -9.35      -5.61
# Maximum Drawdown (%)      -5.18      -2.12     -22.62      -5.58
# Maximum Drawdown (%)      -3.66      -6.70     -11.95      -9.10
# Maximum Drawdown (%)      -1.29     -17.95     -16.03     -12.04
# Maximum Drawdown (%)      -0.00      -0.00      -0.00      -0.00
# Maximum Drawdown (%)      -1.38     -18.53      -9.88      -4.44
